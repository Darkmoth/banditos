# %%
import pandas as pd
import numpy as np
import math
import datetime
import subprocess
import bandit.main as bd

# %%
def get_frame(filename):
    df = pd.read_excel(io=filename)
    # df_combined = pd.merge(df,df_lookup,on='Difficulty')
    # df_combined['Duration'] = df_combined['Time'].apply(lambda x: pd.Timedelta(str(x))).astype('timedelta64[s]')
    # df_combined['MatRate'] = df_combined['Mats'] / df_combined['Duration']
    # df_combined['DiffClass'] = df_combined['Class'] + '-' + df_combined['Difficulty']
    return df

# %%
def save_excel(df,col):
    dfgb = df.groupby([col])
    dfgb = dfgb['Quality'].agg(['count','mean', 'var']).reset_index()
    dfgb.to_excel('AllProjectList.xlsx')
    return dfgb

# %%
subprocess.Popen('ProjectTime.xlsx', shell=True)

# %%
df = get_frame('ProjectTime.xlsx')

# %%
# reduce it
df = bd.reduce(df,'Project')
df['Duration'] = df['Duration'].apply(lambda x: pd.Timedelta(str(x))).astype('timedelta64[s]')
df_quality = bd.get_quality(df['Duration'])
df = df.join(df_quality)
# Out:
# 31 0.9225 29

# %%
df.tail(10)
# Out:
#            Project  ProjeDate  Duration   Quality
# 30  SpotifyPlayGen 2018-09-03    2894.0  0.613141
# 31    FlaskMegaTut 2018-09-08    4154.0  1.000000
# 32    FlaskMegaTut 2018-09-08    3908.0  0.924470
# 33    FlaskMegaTut 2018-09-11    1919.0  0.313786
# 34    FlaskMegaTut 2018-09-12    2193.0  0.397912
# 35    FlaskMegaTut 2018-09-18    1581.0  0.210009
# 36    FlaskMegaTut 2018-09-21    1895.0  0.306417
# 37        VueClass 2018-09-28     897.0  0.000000
# 38    FlaskMegaTut 2018-10-05    3000.0  0.645686
# 39       Octoparse 2018-10-07    1548.0  0.199877

# %%
df.sort_values('Quality', ascending=False).head(10)
# Out:
#               Project  ProjeDate  Duration   Quality
# 31       FlaskMegaTut 2018-09-08    4154.0  1.000000
# 32       FlaskMegaTut 2018-09-08    3908.0  0.924470
# 23     SpotifyPlayGen 2018-08-04    3260.0  0.725514
# 38       FlaskMegaTut 2018-10-05    3000.0  0.645686
# 30     SpotifyPlayGen 2018-09-03    2894.0  0.613141
# 20  GoogleCrashCourse 2018-07-29    2880.0  0.608842
# 17    ZeroToDeepLearn 2018-07-22    2748.0  0.568314
# 16    ZeroToDeepLearn 2018-07-20    2620.0  0.529014
# 22     SpotifyPlayGen 2018-08-02    2584.0  0.517961
# 18  GoogleCrashCourse 2018-07-24    2520.0  0.498311

# %%
dfgb = save_excel(df,'Project')

# %%
df = df.merge(dfgb)
dfgb['total'] = dfgb['count'].sum()
dfgb['donext'] = dfgb.apply(lambda x: bd.get_tuned_ucb(x, 'mean', 'var'), axis=1)
dfgb.sort_values('donext', ascending=False)
# Out:
#              Project  count      mean       var  total    donext
# 4          Octoparse      1  0.199877       NaN     38  1.153500
# 2       FlaskMegaTut      7  0.542612  0.100893     38  0.903047
# 5     SpotifyPlayGen      6  0.492222  0.024257     38  0.881537
# 6       TrollSniffer      3  0.302323  0.000739     38  0.852898
# 0        CUDAproject      4  0.368898  0.002970     38  0.845709
# 3  GoogleCrashCourse      4  0.351320  0.064747     38  0.828132
# 8    ZeroToDeepLearn      6  0.426824  0.020609     38  0.816139
# 1        FindYourJoy      4  0.289146  0.002962     38  0.765958
# 7           VueClass      3  0.123119  0.011488     38  0.673694
