# %%
import pandas as pd
import numpy as np
import subprocess
from datetime import date
import calendar
import bandit.main as bd

# %%
def set_cohorts(source_df, score_col):
    cohort_size = 3
    cohort_size_2 = cohort_size**2
    cohort_size_3 = cohort_size**3

    # break out distinct scores
    uniq_list = source_df[score_col].unique()
    df = pd.DataFrame({score_col : uniq_list}).sort_values(score_col, ascending=True)
    df = df.sort_values (score_col)
    df = df.reset_index (drop=True)
    
    if len (df) > cohort_size:
        grp_size = len (df) / cohort_size
        df['cohort1'] = df.index // grp_size

    if len (df) > cohort_size_2:
        grp_size = len (df) / cohort_size_2
        df['cohort2'] = df.index // grp_size
        
    if len (df) > cohort_size_3:
        grp_size = len (df) / cohort_size_3
        df['cohort3'] = df.index // grp_size

    return df

# %%
def df_bandit_class(df, classname):
    dfgb = df.groupby([classname])
    dfgb = dfgb['Quality'].agg(['count','mean', 'var']).reset_index()
    dfgb['total'] = dfgb['count'].sum()
    dfgb['donext'] = dfgb.apply(lambda x: bd.get_tuned_ucb(x, 'mean', 'var'), axis=1).fillna(999)
    foo = dfgb.sort_values('donext', ascending=False)
    return foo

# %%
def df_search(df_in, cohort):
    if not cohort in df_in:
        return df_in

    df_class = df_bandit_class(df_in, cohort)
    print(df_class)
    next_class = df_class.iloc[0, 0]
    if df_in['Complete'].isnull().sum() > 0:
        df_filtered = df_in[df_in[cohort] == next_class]
    else:
        df_filtered = df_in

    return df_filtered

# %%
def rate_calc(df):
    pedal_time = df['Goal'] * df['seconds']
    rest_time = (df['Goal'] - 1) * 15
    total_time = pedal_time + rest_time
    rate = pedal_time / total_time
    score = pedal_time * rate
    return int(score)

# %%
currDate = date.today()
list = [[x, y] for x in range(1,31) for y in [30,45,60,90,120]]

# %%
df = pd.DataFrame.from_records(list).rename(index=str, columns={0: "Goal", 1: "seconds"})
df['Date'] = currDate
df['Complete'] = np.nan
df = df[['Date','Goal','seconds','Complete']]
# df.to_excel('Outputtest.xlsx')
sheet_info = pd.read_excel(io='BikeGoals.xlsx')
df = df.append(sheet_info).reset_index(drop=True)

# %%
df['Value'] = df.apply(rate_calc, axis=1)
val_df = set_cohorts(df, 'Value')
df = df.merge(val_df, on='Value')

# %%
subprocess.Popen('BikeGoals.xlsx', shell=True)

# %%
# todo - score partial runs
df['Score'] = np.where(df['Complete'] >= df['Goal'], df['Value']**1.2, 0)
df.loc[df['Complete'].isnull(), 'Score'] = np.NaN
df['Class'] = df['Goal'].map(str) + '-' + df['seconds'].map(str)
df = bd.reduce(df,'Class')
# Out:
# 6 0.985 6

# %%
df_quality = bd.get_quality(df['Score'])
df = df.join(df_quality)

# %%
df_step1 = df_search(df,'cohort1')
df_step1
# Out:
#    cohort1  count      mean       var  total    donext
# 0     -0.0      3  0.529963  0.224157      6  0.916374
# 1      1.0      1  0.000000       NaN      6  0.669283
# 2      2.0      2  0.000000  0.000000      6  0.473255
#                     Date  Goal  seconds  Complete  Value  cohort1  cohort2  \
# 91            2018-10-07    18       30       NaN    366      0.0      2.0
# 96            2018-10-07    19       30       NaN    386      0.0      2.0
# 101           2018-10-07    20       30       NaN    406      0.0      2.0
# 106           2018-10-07    21       30       NaN    426      0.0      2.0
# 111           2018-10-07    22       30       NaN    446      0.0      2.0
#
#      cohort3        Score  Class   Quality
# 0       -0.0          NaN   1-30       NaN
# 1       -0.0    59.230515   1-30  0.053168
# 2        0.0          NaN   1-45       NaN
# 3        0.0          NaN   1-60       NaN
# 4        1.0          NaN   1-90       NaN
# 5        2.0          NaN  1-120       NaN
# 6        0.0          NaN   2-30       NaN
# 7        0.0          NaN   2-45       NaN
# 8        1.0          NaN   2-60       NaN
# 9        2.0          NaN   2-90       NaN
# 10       2.0          NaN   8-30       NaN
# 11       4.0          NaN  2-120       NaN
# 12       0.0          NaN   3-30       NaN
# 13       1.0          NaN   3-45       NaN
# 14       2.0          NaN   3-60       NaN
# 15       4.0          NaN   3-90       NaN
# 16       6.0          NaN  3-120       NaN
# 17       1.0          NaN   4-30       NaN
# 18       2.0          NaN   4-45       NaN
# 19       3.0          NaN   4-60       NaN
# 20       6.0          NaN   4-90       NaN
# 21       8.0          NaN  4-120       NaN
# 22       1.0          NaN   5-30       NaN
# 23       3.0          NaN   5-45       NaN
# 24       4.0          NaN   5-60       NaN
# 25       7.0          NaN   5-90       NaN
# 27       2.0          NaN   6-30       NaN
# 28       3.0          NaN   6-45       NaN
# 29       5.0          NaN   6-60       NaN
# 32       2.0          NaN   7-30       NaN
# 33       4.0          NaN   7-45       NaN
# 34       6.0          NaN   7-60       NaN
# 37       5.0          NaN   8-45       NaN
# 38       7.0          NaN   8-60       NaN
# 41       3.0          NaN   9-30       NaN
# 42       6.0          NaN   9-45       NaN
# 43       8.0          NaN   9-60       NaN
# 46       3.0          NaN  10-30       NaN
# 47       3.0   597.916674  10-30  0.536722
# 48       6.0          NaN  10-45       NaN
# 49       6.0          NaN  17-30       NaN
# 50       6.0  1114.015718  10-45  1.000000
# 55       4.0          NaN  11-30       NaN
# 56       7.0          NaN  11-45       NaN
# 60       4.0          NaN  12-30       NaN
# 61       8.0          NaN  12-45       NaN
# 65       5.0          NaN  13-30       NaN
# 71       5.0          NaN  14-30       NaN
# 77       5.0          NaN  15-30       NaN
# 82       6.0          NaN  16-30       NaN
# 91       7.0          NaN  18-30       NaN
# 96       7.0          NaN  19-30       NaN
# 101      8.0          NaN  20-30       NaN
# 106      8.0          NaN  21-30       NaN
# 111      8.0          NaN  22-30       NaN

# %%
df_step2 = df_search(df_step1,'cohort2')
df_step2
# Out:
#    cohort2  count      mean  var  total    donext
# 2      2.0      1  1.000000  NaN      3  1.524074
# 1      1.0      1  0.536722  NaN      3  1.060795
# 0     -0.0      1  0.053168  NaN      3  0.577242
#                     Date  Goal  seconds  Complete  Value  cohort1  cohort2  \
# 16            2018-10-07     3      120       NaN    332      0.0      2.0
# 20            2018-10-07     4       90       NaN    320      0.0      2.0
# 21            2018-10-07     4      120       NaN    438      0.0      2.0
# 25            2018-10-07     5       90       NaN    397      0.0      2.0
# 34            2018-10-07     7       60       NaN    345      0.0      2.0
# 38            2018-10-07     8       60       NaN    393      0.0      2.0
# 42            2018-10-07     9       45       NaN    312      0.0      2.0
# 43            2018-10-07     9       60       NaN    441      0.0      2.0
# 48            2018-10-07    10       45       NaN    346      0.0      2.0
# 49            2018-10-07    17       30       NaN    346      0.0      2.0
# 50   2018-10-07 00:00:00    10       45      10.0    346      0.0      2.0
# 56            2018-10-07    11       45       NaN    379      0.0      2.0
# 61            2018-10-07    12       45       NaN    413      0.0      2.0
# 82            2018-10-07    16       30       NaN    326      0.0      2.0
# 91            2018-10-07    18       30       NaN    366      0.0      2.0
# 96            2018-10-07    19       30       NaN    386      0.0      2.0
# 101           2018-10-07    20       30       NaN    406      0.0      2.0
# 106           2018-10-07    21       30       NaN    426      0.0      2.0
# 111           2018-10-07    22       30       NaN    446      0.0      2.0
#
#      cohort3        Score  Class  Quality
# 16       6.0          NaN  3-120      NaN
# 20       6.0          NaN   4-90      NaN
# 21       8.0          NaN  4-120      NaN
# 25       7.0          NaN   5-90      NaN
# 34       6.0          NaN   7-60      NaN
# 38       7.0          NaN   8-60      NaN
# 42       6.0          NaN   9-45      NaN
# 43       8.0          NaN   9-60      NaN
# 48       6.0          NaN  10-45      NaN
# 49       6.0          NaN  17-30      NaN
# 50       6.0  1114.015718  10-45      1.0
# 56       7.0          NaN  11-45      NaN
# 61       8.0          NaN  12-45      NaN
# 82       6.0          NaN  16-30      NaN
# 91       7.0          NaN  18-30      NaN
# 96       7.0          NaN  19-30      NaN
# 101      8.0          NaN  20-30      NaN
# 106      8.0          NaN  21-30      NaN
# 111      8.0          NaN  22-30      NaN

# %%
df_step3 = df_search(df_step2,'cohort3')
df_step3
# Out:
#    cohort3  count  mean  var  total  donext
# 1      7.0      0   NaN  NaN      1   999.0
# 2      8.0      0   NaN  NaN      1   999.0
# 0      6.0      1   1.0  NaN      1     1.0
#           Date  Goal  seconds  Complete  Value  cohort1  cohort2  cohort3  \
# 25  2018-10-07     5       90       NaN    397      0.0      2.0      7.0
# 38  2018-10-07     8       60       NaN    393      0.0      2.0      7.0
# 56  2018-10-07    11       45       NaN    379      0.0      2.0      7.0
# 91  2018-10-07    18       30       NaN    366      0.0      2.0      7.0
# 96  2018-10-07    19       30       NaN    386      0.0      2.0      7.0
#
#     Score  Class  Quality
# 25    NaN   5-90      NaN
# 38    NaN   8-60      NaN
# 56    NaN  11-45      NaN
# 91    NaN  18-30      NaN
# 96    NaN  19-30      NaN

# %%
df_bandit_class(df_step3, 'Class')
# Out:
#    Class  count  mean  var  total  donext
# 0  11-45      0   NaN  NaN      0   999.0
# 1  18-30      0   NaN  NaN      0   999.0
# 2  19-30      0   NaN  NaN      0   999.0
# 3   5-90      0   NaN  NaN      0   999.0
# 4   8-60      0   NaN  NaN      0   999.0
