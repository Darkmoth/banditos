# %%
import pandas as pd
import numpy as np
import math
from datetime import date, time, datetime, timedelta
import subprocess
import bandit.main as bd
import calendar

# %%
def set_cohorts(source_df, score_col):
    cohort_size = 3
    cohort_size_2 = cohort_size**2
    cohort_size_3 = cohort_size**3

    # break out distinct scores
    uniq_list = source_df[score_col].unique()
    df = pd.DataFrame({score_col : uniq_list}).sort_values(score_col, ascending=True)
    df = df.sort_values (score_col)
    df = df.reset_index (drop=True)
    
    if len (df) > cohort_size:
        grp_size = len (df) / cohort_size
        df['cohort1'] = df.index // grp_size

    if len (df) > cohort_size_2:
        grp_size = len (df) / cohort_size_2
        df['cohort2'] = df.index // grp_size
        
    if len (df) > cohort_size_3:
        grp_size = len (df) / cohort_size_3
        df['cohort3'] = df.index // grp_size

    return df

# %%
def df_search(df_in, cohort):
    if not cohort in df_in:
        return df_in

    df_class = df_bandit_class(df_in, cohort)
    print(df_class)
    next_class = df_class.iloc[0, 0]
    if df_in['Complete'].isnull().sum() > 0:
        df_filtered = df_in[df_in[cohort] == next_class]
    else:
        df_filtered = df_in
        
    return df_filtered

# %%
def set_start(df):
    goal_minutes = df['Goal']
    final = datetime.combine(date.today(), time(0, 0)) + timedelta(minutes=goal_minutes)
    return final

# %%
# todo: combine bandit_class and bandit_diff
def df_bandit_class(df, classname):
    dfgb = df.groupby([classname])
    dfgb = dfgb['Quality'].agg(['count','mean', 'var']).reset_index()
    dfgb['total'] = dfgb['count'].sum()
    dfgb['donext'] = dfgb.apply(lambda x: bd.get_tuned_ucb(x, 'mean', 'var'), axis=1).fillna(999)
    
    # set up the time
    # dfgb['CanStart'] = dfgb.apply(set_start, axis=1)
    
    foo = dfgb.sort_values('donext', ascending=False)
    return foo

# %%
# timelist = [datetime.combine(date.today(), time(0, 0)) + timedelta(minutes=i) for i in  range(0,1440,5)]
minute_list = [i for i in  range(5,1440,5)]
df = pd.DataFrame({"Start":minute_list})

# %%
currDate = datetime.today()
minute_list = [i for i in  range(5,1440,5)]
df = pd.DataFrame({"Goal":minute_list})
df["Date"] = currDate
df["Complete"] = np.nan
df = df[['Date', 'Goal', 'Complete']]

# %%
subprocess.Popen('StopSmoking.xlsx', shell=True)

# %%
df_excel = pd.read_excel(io='StopSmoking.xlsx')
df = df.append(df_excel).reset_index(drop=True)

# %%
df = bd.reduce(df,'Goal')
# Out:
# 4 0.99 4

# %%
df.tail(10)
# Out:
#                           Date  Goal  Complete
# 281 2018-10-09 06:04:27.898516  1410       NaN
# 282 2018-10-09 06:04:27.898516  1415       NaN
# 283 2018-10-09 06:04:27.898516  1420       NaN
# 284 2018-10-09 06:04:27.898516  1425       NaN
# 285 2018-10-09 06:04:27.898516  1430       NaN
# 286 2018-10-09 06:04:27.898516  1435       NaN
# 287 2018-10-06 00:00:00.000000     5       1.0
# 288 2018-10-07 00:00:00.000000   485       1.0
# 289 2018-10-08 00:00:00.000000   965       1.0
# 290 2018-10-08 00:00:00.000000  1125       NaN

# %%
df['Score'] = np.where(df['Complete'] >= 1, df['Goal']**1.2, 0)
df.loc[df['Complete'].isnull(), 'Score'] = np.NaN

# %%
df_quality = bd.get_quality(df['Score'])

# %%
df = df.join(df_quality).sort_values('Quality', ascending=False)

# %%
val_df = set_cohorts(df, 'Goal')
df = df.merge(val_df, on='Goal')

# %%
currDay = calendar.day_name[currDate.weekday()]
df_today = df
df_today['weekday'] = df_today['Date'].dt.day_name()
df_today = df_today[df_today['weekday'] == currDay]
today_sum = df_today['Complete'].notnull().sum()
if today_sum >= 10:
    df = df_today

# %%
df.sort_values('Date', ascending=True).tail(10)
# Out:
#                           Date  Goal  Complete  Score  Quality  cohort1  \
# 100 2018-10-09 06:04:27.898516   480       NaN    NaN      NaN      0.0
# 99  2018-10-09 06:04:27.898516   475       NaN    NaN      NaN      0.0
# 98  2018-10-09 06:04:27.898516   470       NaN    NaN      NaN      0.0
# 97  2018-10-09 06:04:27.898516   465       NaN    NaN      NaN      0.0
# 96  2018-10-09 06:04:27.898516   460       NaN    NaN      NaN      0.0
# 95  2018-10-09 06:04:27.898516   455       NaN    NaN      NaN      0.0
# 94  2018-10-09 06:04:27.898516   450       NaN    NaN      NaN      0.0
# 93  2018-10-09 06:04:27.898516   445       NaN    NaN      NaN      0.0
# 289 2018-10-09 06:04:27.898516  1430       NaN    NaN      NaN      2.0
# 290 2018-10-09 06:04:27.898516  1435       NaN    NaN      NaN      2.0
#
#      cohort2  cohort3  weekday
# 100      2.0      8.0  Tuesday
# 99       2.0      8.0  Tuesday
# 98       2.0      8.0  Tuesday
# 97       2.0      8.0  Tuesday
# 96       2.0      8.0  Tuesday
# 95       2.0      8.0  Tuesday
# 94       2.0      8.0  Tuesday
# 93       2.0      8.0  Tuesday
# 289      8.0     26.0  Tuesday
# 290      8.0     26.0  Tuesday

# %%
df = df.sort_values('Quality', ascending=False)
df.head(10)
# Out:
#                         Date  Goal  Complete        Score   Quality  cohort1  \
# 0 2018-10-08 00:00:00.000000   965       1.0  3814.457461  1.000000      2.0
# 2 2018-10-07 00:00:00.000000   485       1.0  1670.667739  0.436965      1.0
# 4 2018-10-06 00:00:00.000000     5       1.0     6.898648  0.000000     -0.0
# 1 2018-10-09 06:04:27.898516   965       NaN          NaN       NaN      2.0
# 3 2018-10-09 06:04:27.898516   485       NaN          NaN       NaN      1.0
# 5 2018-10-09 06:04:27.898516     5       NaN          NaN       NaN     -0.0
# 6 2018-10-09 06:04:27.898516    10       NaN          NaN       NaN      0.0
# 7 2018-10-09 06:04:27.898516    15       NaN          NaN       NaN      0.0
# 8 2018-10-09 06:04:27.898516    20       NaN          NaN       NaN      0.0
# 9 2018-10-09 06:04:27.898516    25       NaN          NaN       NaN      0.0
#
#    cohort2  cohort3   weekday
# 0      6.0     18.0    Monday
# 2      3.0      9.0    Sunday
# 4     -0.0     -0.0  Saturday
# 1      6.0     18.0   Tuesday
# 3      3.0      9.0   Tuesday
# 5     -0.0     -0.0   Tuesday
# 6      0.0      0.0   Tuesday
# 7      0.0      0.0   Tuesday
# 8      0.0      0.0   Tuesday
# 9      0.0      0.0   Tuesday

# %%
df_step1 = df_search(df,'cohort1')
df_step1
# Out:
#    cohort1  count      mean  var  total    donext
# 2      2.0      1  1.000000  NaN      3  1.524074
# 1      1.0      1  0.436965  NaN      3  0.961038
# 0     -0.0      1  0.000000  NaN      3  0.524074
#                           Date  Goal  Complete        Score  Quality  cohort1  \
# 0   2018-10-08 00:00:00.000000   965       1.0  3814.457461      1.0      2.0
# 1   2018-10-09 06:04:27.898516   965       NaN          NaN      NaN      2.0
# 234      7.0     21.0  Tuesday
# 235      7.0     21.0  Tuesday
# 236      7.0     21.0  Tuesday
# 237      7.0     21.0  Tuesday
# 238      7.0     22.0  Tuesday
# 239      7.0     22.0  Tuesday
# 240      7.0     22.0  Tuesday
# 241      7.0     22.0  Tuesday
# 242      7.0     22.0  Tuesday
# 243      7.0     22.0  Tuesday
# 244      7.0     22.0  Tuesday
# 245      7.0     22.0  Tuesday
# 246      7.0     22.0  Tuesday
# 247      7.0     22.0  Tuesday
# 248      7.0     22.0  Tuesday
# 249      7.0     23.0  Tuesday
# 250      7.0     23.0  Tuesday
# 251      7.0     23.0  Tuesday
# 252      7.0     23.0  Tuesday
# 253      7.0     23.0  Tuesday
# 254      7.0     23.0  Tuesday
# 255      7.0     23.0  Tuesday
# 256      7.0     23.0  Tuesday
# 257      7.0     23.0  Tuesday
# 258      7.0     23.0  Tuesday
# 259      7.0     23.0  Tuesday

# %%
df_step3 = df_search(df_step2,'cohort3')
df_step3
# Out:
#    cohort3  count  mean  var  total  donext
# 0     21.0      0   NaN  NaN      0   999.0
# 1     22.0      0   NaN  NaN      0   999.0
# 2     23.0      0   NaN  NaN      0   999.0
#                           Date  Goal  Complete  Score  Quality  cohort1  \
# 227 2018-10-09 06:04:27.898516  1125       NaN    NaN      NaN      2.0
# 228 2018-10-08 00:00:00.000000  1125       NaN    NaN      NaN      2.0
# 229 2018-10-09 06:04:27.898516  1130       NaN    NaN      NaN      2.0
# 230 2018-10-09 06:04:27.898516  1135       NaN    NaN      NaN      2.0
# 231 2018-10-09 06:04:27.898516  1140       NaN    NaN      NaN      2.0
# 232 2018-10-09 06:04:27.898516  1145       NaN    NaN      NaN      2.0
# 233 2018-10-09 06:04:27.898516  1150       NaN    NaN      NaN      2.0
# 234 2018-10-09 06:04:27.898516  1155       NaN    NaN      NaN      2.0
# 235 2018-10-09 06:04:27.898516  1160       NaN    NaN      NaN      2.0
# 236 2018-10-09 06:04:27.898516  1165       NaN    NaN      NaN      2.0
# 237 2018-10-09 06:04:27.898516  1170       NaN    NaN      NaN      2.0
#
#      cohort2  cohort3  weekday
# 227      7.0     21.0  Tuesday
# 228      7.0     21.0   Monday
# 229      7.0     21.0  Tuesday
# 230      7.0     21.0  Tuesday
# 231      7.0     21.0  Tuesday
# 232      7.0     21.0  Tuesday
# 233      7.0     21.0  Tuesday
# 234      7.0     21.0  Tuesday
# 235      7.0     21.0  Tuesday
# 236      7.0     21.0  Tuesday
# 237      7.0     21.0  Tuesday

# %%
df = df_bandit_class(df_step3, 'Goal')
df['CanStart'] = df.apply(set_start, axis=1).dt.strftime('%I:%M %p')
df
# Out:
#    Goal  count  mean  var  total  donext  CanStart
# 0  1125      0   NaN  NaN      0   999.0  06:45 PM
# 1  1130      0   NaN  NaN      0   999.0  06:50 PM
# 2  1135      0   NaN  NaN      0   999.0  06:55 PM
# 3  1140      0   NaN  NaN      0   999.0  07:00 PM
# 4  1145      0   NaN  NaN      0   999.0  07:05 PM
# 5  1150      0   NaN  NaN      0   999.0  07:10 PM
# 6  1155      0   NaN  NaN      0   999.0  07:15 PM
# 7  1160      0   NaN  NaN      0   999.0  07:20 PM
# 8  1165      0   NaN  NaN      0   999.0  07:25 PM
# 9  1170      0   NaN  NaN      0   999.0  07:30 PM
